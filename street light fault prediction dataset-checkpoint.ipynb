# %% [markdown]
# # Predictive Analysis of Street Light operations: Exploring environmental factors and Fault Detection in Urban Lighting Infrastructure

# %%
#importing dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from imblearn.over_sampling import SMOTE
import os
import joblib
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

# %%
#uploading dataset

# %%
df = pd.read_csv(r'datasets/dataset.csv')
df.head()
# Out:
#    bulb_number            timestamp  power_consumption (Watts)  \
# 0            1  2023-09-06 07:53:23                     106.18
# 1            1  2023-03-28 16:28:29                      58.71
# 2            1  2023-09-20 19:17:46                     195.49
# 3            1  2023-02-03 18:19:43                      95.64
# 4            1  2023-01-12 13:43:48                      70.92
#
#    voltage_levels (Volts)  current_fluctuations (Amperes)  \
# 0                  238.52                        6.127984
# 1                  235.99                        3.010000
# 2                  234.97                        1.060000
# 3                  225.74                        2.160000
# 4                  218.76                        1.830000
#
#    temperature (Celsius) environmental_conditions  \
# 0                  21.97                    Rainy
# 1                  24.16                    Clear
# 2                  13.64                    Rainy
# 3                  15.82                    Rainy
# 4                  19.12                    Rainy
#
#    current_fluctuations_env (Amperes)  fault_type
# 0                            0.780000           1
# 1                            0.100000           0
# 2                            0.920000           0
# 3                            3.060000           0
# 4                            6.529021           4

# %%
#data analysis

# %%
Label =  ('No fault', 'Short circuit', 'Voltage Surge', 'Bulb failure', 'Light Flickering')
Label
# Out:
# ('No fault',
#  'Short circuit',
#  'Voltage Surge',
#  'Bulb failure',
#  'Light Flickering')

# %%
#Data Visulazation

# %%
sns.set(style="darkgrid") 
plt.figure(figsize=(12, 6)) 
ax = sns.countplot(x=df['fault_type'], data=df, palette="Set3")
plt.title("Count Plot")  
plt.xlabel("Categories") 
plt.ylabel("Count") 
ax.set_xticklabels(Label)

for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
                textcoords='offset points')

plt.show()

# %%
#Label Encoding

# %%
le = LabelEncoder()
df['environmental_conditions']=le.fit_transform(df['environmental_conditions'])
df.head()
# Out:
#    bulb_number            timestamp  power_consumption (Watts)  \
# 0            1  2023-09-06 07:53:23                     106.18
# 1            1  2023-03-28 16:28:29                      58.71
# 2            1  2023-09-20 19:17:46                     195.49
# 3            1  2023-02-03 18:19:43                      95.64
# 4            1  2023-01-12 13:43:48                      70.92
#
#    voltage_levels (Volts)  current_fluctuations (Amperes)  \
# 0                  238.52                        6.127984
# 1                  235.99                        3.010000
# 2                  234.97                        1.060000
# 3                  225.74                        2.160000
# 4                  218.76                        1.830000
#
#    temperature (Celsius)  environmental_conditions  \
# 0                  21.97                         2
# 1                  24.16                         0
# 2                  13.64                         2
# 3                  15.82                         2
# 4                  19.12                         2
#
#    current_fluctuations_env (Amperes)  fault_type
# 0                            0.780000           1
# 1                            0.100000           0
# 2                            0.920000           0
# 3                            3.060000           0
# 4                            6.529021           4

# %%
#Data Visulazation

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'])

df['year'] = df['timestamp'].dt.year
df['month'] = df['timestamp'].dt.month
df['day'] = df['timestamp'].dt.day
df['hour'] = df['timestamp'].dt.hour
df['minute'] = df['timestamp'].dt.minute
df['second'] = df['timestamp'].dt.second

print(df.head())
# Out:
#    bulb_number           timestamp  power_consumption (Watts)  \
# 0            1 2023-09-06 07:53:23                     106.18
# 1            1 2023-03-28 16:28:29                      58.71
# 2            1 2023-09-20 19:17:46                     195.49
# 3            1 2023-02-03 18:19:43                      95.64
# 4            1 2023-01-12 13:43:48                      70.92
#
#    voltage_levels (Volts)  current_fluctuations (Amperes)  \
# 0                  238.52                        6.127984
# 1                  235.99                        3.010000
# 2                  234.97                        1.060000
# 3                  225.74                        2.160000
# 4                  218.76                        1.830000
#
#    temperature (Celsius)  environmental_conditions  \
# 0                  21.97                         2
# 1                  24.16                         0
# 2                  13.64                         2
# 3                  15.82                         2
# 4                  19.12                         2
#
#    current_fluctuations_env (Amperes)  fault_type  year  month  day  hour  \
# 0                            0.780000           1  2023      9    6     7
# 1                            0.100000           0  2023      3   28    16
# 2                            0.920000           0  2023      9   20    19
# 3                            3.060000           0  2023      2    3    18
# 4                            6.529021           4  2023      1   12    13
#
#    minute  second
# 0      53      23
# 1      28      29
# 2      17      46
# 3      19      43
# 4      43      48

# %%
#data Correlection

# %%
df.corr()
# Out:
#                                     bulb_number  power_consumption (Watts)  \
# bulb_number                            1.000000                  -0.000226
# power_consumption (Watts)             -0.000226                   1.000000
# voltage_levels (Volts)                 0.006707                   0.009576
# current_fluctuations (Amperes)        -0.001015                   0.007381
# temperature (Celsius)                  0.003853                  -0.001573
# environmental_conditions               0.001122                   0.041784
# current_fluctuations_env (Amperes)     0.002622                   0.011066
# fault_type                            -0.003233                  -0.069211
# year                                        NaN                        NaN
# month                                 -0.004611                  -0.000421
# day                                    0.002766                  -0.004167
# hour                                   0.004286                  -0.006827
# minute                                -0.005726                   0.007493
# second                                 0.000778                  -0.007711
#
#                                     voltage_levels (Volts)  \
# bulb_number                                       0.006707
# power_consumption (Watts)                         0.009576
# voltage_levels (Volts)                            1.000000
# current_fluctuations (Amperes)                   -0.012158
# temperature (Celsius)                            -0.000262
# environmental_conditions                         -0.035620
# current_fluctuations_env (Amperes)               -0.011844
# fault_type                                        0.066861
# year                                                   NaN
# month                                            -0.004011
# day                                               0.001937
# hour                                              0.002052
# minute                                            0.000805
# second                                           -0.001249
#
#                                     current_fluctuations (Amperes)  \
# bulb_number                                              -0.001015
# power_consumption (Watts)                                 0.007381
# voltage_levels (Volts)                                   -0.012158
# current_fluctuations (Amperes)                            1.000000
# temperature (Celsius)                                    -0.000262
# environmental_conditions                                  0.053208
# current_fluctuations_env (Amperes)                       -0.016370
# fault_type                                                0.014191
# year                                                           NaN
# month                                                    -0.010295
# day                                                       0.002957
# hour                                                     -0.005756
# minute                                                    0.005745
# second                                                    0.005466
#
#                                     temperature (Celsius)  \
# bulb_number                                      0.003853
# power_consumption (Watts)                       -0.001573
# voltage_levels (Volts)                          -0.000262
# current_fluctuations (Amperes)                  -0.000262
# temperature (Celsius)                            1.000000
# environmental_conditions                         0.008267
# current_fluctuations_env (Amperes)              -0.001836
# fault_type                                       0.002889
# year                                                  NaN
# month                                            0.003572
# day                                             -0.002646
# hour                                             0.003374
# minute                                          -0.000951
# second                                           0.000133
#
#                                     environmental_conditions  \
# bulb_number                                         0.001122
# power_consumption (Watts)                           0.041784
# voltage_levels (Volts)                             -0.035620
# current_fluctuations (Amperes)                      0.053208
# temperature (Celsius)                               0.008267
# environmental_conditions                            1.000000
# current_fluctuations_env (Amperes)                  0.098336
# fault_type                                         -0.040875
# year                                                     NaN
# month                                              -0.000309
# day                                                -0.001266
# hour                                                0.004669
# minute                                              0.002567
# second                                              0.002368
#
#                                     current_fluctuations_env (Amperes)  \
# bulb_number                                                   0.002622
# power_consumption (Watts)                                     0.011066
# voltage_levels (Volts)                                       -0.011844
# current_fluctuations (Amperes)                               -0.016370
# temperature (Celsius)                                        -0.001836
# environmental_conditions                                      0.098336
# current_fluctuations_env (Amperes)                            1.000000
# fault_type                                                    0.425605
# year                                                               NaN
# month                                                        -0.001811
# day                                                           0.006938
# hour                                                          0.003262
# minute                                                        0.002994
# second                                                       -0.002166
#
#                                     fault_type  year     month       day  \
# bulb_number                          -0.003233   NaN -0.004611  0.002766
# power_consumption (Watts)            -0.069211   NaN -0.000421 -0.004167
# voltage_levels (Volts)                0.066861   NaN -0.004011  0.001937
# current_fluctuations (Amperes)        0.014191   NaN -0.010295  0.002957
# temperature (Celsius)                 0.002889   NaN  0.003572 -0.002646
# environmental_conditions             -0.040875   NaN -0.000309 -0.001266
# current_fluctuations_env (Amperes)    0.425605   NaN -0.001811  0.006938
# fault_type                            1.000000   NaN  0.006578  0.010423
# year                                       NaN   NaN       NaN       NaN
# month                                 0.006578   NaN  1.000000  0.013145
# day                                   0.010423   NaN  0.013145  1.000000
# hour                                  0.000320   NaN  0.000186  0.002642
# minute                               -0.000942   NaN -0.006237  0.005542
# second                                0.001207   NaN  0.001208 -0.008258
#
#                                         hour    minute    second
# bulb_number                         0.004286 -0.005726  0.000778
# power_consumption (Watts)          -0.006827  0.007493 -0.007711
# voltage_levels (Volts)              0.002052  0.000805 -0.001249
# current_fluctuations (Amperes)     -0.005756  0.005745  0.005466
# temperature (Celsius)               0.003374 -0.000951  0.000133
# environmental_conditions            0.004669  0.002567  0.002368
# current_fluctuations_env (Amperes)  0.003262  0.002994 -0.002166
# fault_type                          0.000320 -0.000942  0.001207
# year                                     NaN       NaN       NaN
# month                               0.000186 -0.006237  0.001208
# day                                 0.002642  0.005542 -0.008258
# hour                                1.000000 -0.002053 -0.006961
# minute                             -0.002053  1.000000 -0.002851
# second                             -0.006961 -0.002851  1.000000

# %%
#Checking NULL values

# %%
df.isnull().sum()
# Out:
# bulb_number                           0
# timestamp                             0
# power_consumption (Watts)             0
# voltage_levels (Volts)                0
# current_fluctuations (Amperes)        0
# temperature (Celsius)                 0
# environmental_conditions              0
# current_fluctuations_env (Amperes)    0
# fault_type                            0
# year                                  0
# month                                 0
# day                                   0
# hour                                  0
# minute                                0
# second                                0
# dtype: int64

# %%
#Declaring independent and dependent variable

# %%
x = df.drop(['fault_type','timestamp'],axis = 1)
x.head()
# Out:
#    bulb_number  power_consumption (Watts)  voltage_levels (Volts)  \
# 0            1                     106.18                  238.52
# 1            1                      58.71                  235.99
# 2            1                     195.49                  234.97
# 3            1                      95.64                  225.74
# 4            1                      70.92                  218.76
#
#    current_fluctuations (Amperes)  temperature (Celsius)  \
# 0                        6.127984                  21.97
# 1                        3.010000                  24.16
# 2                        1.060000                  13.64
# 3                        2.160000                  15.82
# 4                        1.830000                  19.12
#
#    environmental_conditions  current_fluctuations_env (Amperes)  year  month  \
# 0                         2                            0.780000  2023      9
# 1                         0                            0.100000  2023      3
# 2                         2                            0.920000  2023      9
# 3                         2                            3.060000  2023      2
# 4                         2                            6.529021  2023      1
#
#    day  hour  minute  second
# 0    6     7      53      23
# 1   28    16      28      29
# 2   20    19      17      46
# 3    3    18      19      43
# 4   12    13      43      48

# %%
y = df['fault_type']
y
# Out:
# 0        1
# 1        0
# 2        0
# 3        0
# 4        4
#         ..
# 34305    3
# 34306    3
# 34307    0
# 34308    0
# 34309    0
# Name: fault_type, Length: 34310, dtype: int64

# %%
#Data Balancing

# %%
smote = SMOTE(random_state=42)
x,y = smote.fit_resample(x,y)

# %%
sns.set(style="darkgrid") 
plt.figure(figsize=(12, 6)) 
ax = sns.countplot(x=y, data=df, palette="Set3")
plt.title("Count Plot")  
plt.xlabel("Categories") 
plt.ylabel("Count") 
ax.set_xticklabels(Label)

for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
                textcoords='offset points')

plt.show()

# %%
#Data Splitting

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.3, random_state = 42)

# %%
x_train.shape
# Out:
# (84388, 13)

# %%
#performance evalution

# %%
precision = []
recall = []
fscore = []
accuracy = []


def performance_metrics(algorithm, predict, testY):
    testY = testY.astype('int64')
    predict = predict.astype('int64')
    p = precision_score(testY, predict, average='macro') * 100
    r = recall_score(testY, predict, average='macro') * 100
    f = f1_score(testY, predict, average='macro') * 100
    a = accuracy_score(testY, predict) * 100 
    accuracy.append(a)
    precision.append(p)
    recall.append(r)
    fscore.append(f)
    print(algorithm + ' Accuracy    : ' + str(a))
    print(algorithm + ' Precision   : ' + str(p))
    print(algorithm + ' Recall      : ' + str(r))
    print(algorithm + ' FSCORE      : ' + str(f))
    report = classification_report(testY, predict, target_names=Label)
    print('\n' + algorithm + " classification report\n" + report)
    conf_matrix = confusion_matrix(testY, predict) 
    plt.figure(figsize=(5, 5)) 
    ax = sns.heatmap(conf_matrix, xticklabels=Label, yticklabels=Label, annot=True, cmap="Blues", fmt="g")
    ax.set_ylim([0, len(Label)])
    plt.title(algorithm + " Confusion matrix") 
    plt.ylabel('True class') 
    plt.xlabel('Predicted class') 
    plt.show()

# %%
#KNearestNeighbours Classifier model building

# %%
KMeans = 'model/KNN.npy'
if os.path.exists(KMeans):
    classifier = np.load(KMeans, allow_pickle = True).item()
else:                       
    classifier = KNeighborsClassifier()
    classifier.fit(x_train, y_train)
    np.save('model/KNN', classifier)

y_pred = classifier.predict(x_test)
# Evaluate the model
performance_metrics('KNearestNeighbours Classifier', y_pred, y_test)
# Out:
# KNearestNeighbours Classifier Accuracy    : 86.99090330964691
# KNearestNeighbours Classifier Precision   : 88.41502839752819
# KNearestNeighbours Classifier Recall      : 87.05170818413688
# KNearestNeighbours Classifier FSCORE      : 84.83293790475929
#
# KNearestNeighbours Classifier classification report
#                   precision    recall  f1-score   support
#
#         No fault       0.97      0.39      0.55      7269
#    Short circuit       0.86      1.00      0.93      7274
#    Voltage Surge       0.90      1.00      0.95      7173
#     Bulb failure       0.83      0.98      0.90      7339
# Light Flickering       0.84      0.99      0.91      7112
#
#         accuracy                           0.87     36167
#        macro avg       0.88      0.87      0.85     36167
#     weighted avg       0.88      0.87      0.85     36167

# %%
KMeans = 'model/RFC.joblib'

if os.path.exists(KMeans):
    classifier1 = joblib.load(KMeans)
else:                       
    classifier1 = RandomForestClassifier(n_estimators=100,
    criterion='gini',
    max_depth=None,
    min_samples_split=2,
    min_samples_leaf=1,
    min_weight_fraction_leaf=0.0,
    max_features='auto',
    max_leaf_nodes=None,
    min_impurity_decrease=0.0,
    bootstrap=True,
    oob_score=False,
    n_jobs=None,
    random_state=None,
    verbose=0,
    warm_start=False,
    class_weight=None,
    ccp_alpha=0.0,
    max_samples=None,
)
    classifier1.fit(x_train, y_train)
    joblib.dump(classifier1, 'model/RFC.joblib')

y_pred3 = classifier1.predict(x_test)
# Evaluate the model
performance_metrics('RandomForestClassifier', y_pred3, y_test)
# Out:
# RandomForestClassifier Accuracy    : 93.54383830563773
# RandomForestClassifier Precision   : 93.65290582605601
# RandomForestClassifier Recall      : 93.55426852141987
# RandomForestClassifier FSCORE      : 93.5415433134498
#
# RandomForestClassifier classification report
#                   precision    recall  f1-score   support
#
#         No fault       0.89      0.83      0.86      7269
#    Short circuit       0.99      0.98      0.98      7274
#    Voltage Surge       0.96      0.97      0.96      7173
#     Bulb failure       0.88      0.95      0.91      7339
# Light Flickering       0.98      0.95      0.96      7112
#
#         accuracy                           0.94     36167
#        macro avg       0.94      0.94      0.94     36167
#     weighted avg       0.94      0.94      0.94     36167

# %%
#Tabular form of Performance Metrics

# %%
columns = ["Algorithm Name","Precison","Recall","FScore","Accuracy"]
values = []
algorithm_names = ["KNearestNeighbours Classifier", "Random Forest Classifier"]
for i in range(len(algorithm_names)):
    values.append([algorithm_names[i],precision[i],recall[i],fscore[i],accuracy[i]])
    
temp = pd.DataFrame(values,columns=columns)
temp
# Out:
#                   Algorithm Name   Precison     Recall     FScore   Accuracy
# 0  KNearestNeighbours Classifier  88.415028  87.051708  84.832938  86.990903
# 1       Random Forest Classifier  93.652906  93.554269  93.541543  93.543838

# %%
#Uploading testing dataset

# %%
test=pd.read_csv("datasets/test.csv")

# %%
le = LabelEncoder()
test['environmental_conditions']=le.fit_transform(test['environmental_conditions'])

test['timestamp'] = pd.to_datetime(test['timestamp'])

test['year'] = test['timestamp'].dt.year
test['month'] = test['timestamp'].dt.month
test['day'] = test['timestamp'].dt.day
test['hour'] = test['timestamp'].dt.hour
test['minute'] = test['timestamp'].dt.minute
test['second'] = test['timestamp'].dt.second
test = test.drop(['timestamp'], axis = 1)
test.head()
# Out:
#    bulb_number  power_consumption (Watts)  voltage_levels (Volts)  \
# 0            1                     106.18                  238.52
# 1            1                      58.71                  235.99
# 2            1                     195.49                  234.97
# 3            1                      95.64                  225.74
# 4            1                      70.92                  218.76
#
#    current_fluctuations (Amperes)  temperature (Celsius)  \
# 0                        6.127984                  21.97
# 1                        3.010000                  24.16
# 2                        1.060000                  13.64
# 3                        2.160000                  15.82
# 4                        1.830000                  19.12
#
#    environmental_conditions  current_fluctuations_env (Amperes)  year  month  \
# 0                         2                            0.780000  2023      6
# 1                         0                            0.100000  2023      3
# 2                         2                            0.920000  2023      9
# 3                         2                            3.060000  2023      3
# 4                         2                            6.529021  2023     12
#
#    day  hour  minute  second
# 0    9     7      53       0
# 1   28    16      28       0
# 2   20    19      17       0
# 3    2    18      19       0
# 4    1    13      43       0

# %%
#Model prediction on test data

# %%
predict = classifier1.predict(test)

for i, p in enumerate(predict):
    if p == 0:
        print(test.iloc[i]) 
        print("Model Predicted of Row {} in Test Data is".format(i),Label[0])
    elif p == 1:
        print(test.iloc[i])  
        print("Model Predicted of Row {} in Test Data is".format(i),Label[1])
    elif p == 2:
        print(test.iloc[i])  
        print("Model Predicted of Row {} in Test Data is".format(i),Label[2])
    elif p == 3:
        print(test.iloc[i])
        print("Model Predicted of Row {} in Test Data is".format(i),Label[3])
    else:
        print(test.iloc[i])  
        print("Model Predicted of Row {} in Test Data is".format(i),Label[4])
# Out:
# bulb_number                              1.000000
# power_consumption (Watts)              106.180000
# voltage_levels (Volts)                 238.520000
# current_fluctuations (Amperes)           6.127984
# temperature (Celsius)                   21.970000
# environmental_conditions                 2.000000
# current_fluctuations_env (Amperes)       0.780000
# year                                  2023.000000
# month                                    6.000000
# day                                      9.000000
# hour                                     7.000000
# minute                                  53.000000
# second                                   0.000000
# Name: 0, dtype: float64
# Model Predicted of Row 0 in Test Data is Short circuit
# bulb_number                              1.00
# power_consumption (Watts)               58.71
# voltage_levels (Volts)                 235.99
# current_fluctuations (Amperes)           3.01
# temperature (Celsius)                   24.16
# environmental_conditions                 0.00
# current_fluctuations_env (Amperes)       0.10
# year                                  2023.00
# month                                    3.00
# day                                     28.00
# hour                                    16.00
# minute                                  28.00
# second                                   0.00
# Name: 1, dtype: float64
# Model Predicted of Row 1 in Test Data is No fault
# bulb_number                              1.00
# power_consumption (Watts)              195.49
# voltage_levels (Volts)                 234.97
# current_fluctuations (Amperes)           1.06
# temperature (Celsius)                   13.64
# environmental_conditions                 2.00
# current_fluctuations_env (Amperes)       0.92
# year                                  2023.00
# month                                    9.00
# day                                     20.00
# hour                                    19.00
# minute                                  17.00
# second                                   0.00
# Name: 2, dtype: float64
# Model Predicted of Row 2 in Test Data is No fault
# bulb_number                              1.00
# power_consumption (Watts)               95.64
# voltage_levels (Volts)                 225.74
# current_fluctuations (Amperes)           2.16
# temperature (Celsius)                   15.82
# environmental_conditions                 2.00
# current_fluctuations_env (Amperes)       3.06
# year                                  2023.00
# month                                    3.00
# day                                      2.00
# hour                                    18.00
# minute                                  19.00
# second                                   0.00
# Name: 3, dtype: float64
# Model Predicted of Row 3 in Test Data is No fault
# bulb_number                              1.000000
# power_consumption (Watts)               70.920000
# voltage_levels (Volts)                 218.760000
# current_fluctuations (Amperes)           1.830000
# temperature (Celsius)                   19.120000
# environmental_conditions                 2.000000
# current_fluctuations_env (Amperes)       6.529021
# year                                  2023.000000
# month                                   12.000000
# day                                      1.000000
# hour                                    13.000000
# minute                                  43.000000
# second                                   0.000000
# Name: 4, dtype: float64
# Model Predicted of Row 4 in Test Data is Light Flickering
# bulb_number                              1.000000
# power_consumption (Watts)              115.838968
# voltage_levels (Volts)                 227.770000
# current_fluctuations (Amperes)           0.230000
# temperature (Celsius)                   22.150000
# environmental_conditions                 0.000000
# current_fluctuations_env (Amperes)       0.850000
# year                                  2023.000000
# month                                   11.000000
# day                                      1.000000
# hour                                     7.000000
# minute                                  19.000000
# second                                   0.000000
# Name: 5, dtype: float64
# Model Predicted of Row 5 in Test Data is Bulb failure
# bulb_number                              1.00
# power_consumption (Watts)               56.47
# voltage_levels (Volts)                 236.73
# current_fluctuations (Amperes)           2.64
# temperature (Celsius)                   29.86
# environmental_conditions                 2.00
# current_fluctuations_env (Amperes)       0.37
# year                                  2023.00
# month                                    1.00
# day                                     20.00
# hour                                    11.00
# minute                                  21.00
# second                                   0.00
# Name: 6, dtype: float64
# Model Predicted of Row 6 in Test Data is No fault
# bulb_number                              1.000000
# power_consumption (Watts)              113.989179
# voltage_levels (Volts)                 239.080000
# current_fluctuations (Amperes)           2.620000
# temperature (Celsius)                   22.590000
# environmental_conditions                 1.000000
# current_fluctuations_env (Amperes)       3.480000
# year                                  2023.000000
# month                                   12.000000
# day                                     24.000000
# hour                                     1.000000
# minute                                  18.000000
# second                                   0.000000
# Name: 7, dtype: float64
# Model Predicted of Row 7 in Test Data is No fault
# bulb_number                              1.000000
# power_consumption (Watts)              144.130000
# voltage_levels (Volts)                 247.034115
# current_fluctuations (Amperes)           4.510000
# temperature (Celsius)                   10.910000
# environmental_conditions                 1.000000
# current_fluctuations_env (Amperes)       1.400000
# year                                  2023.000000
# month                                    1.000000
# day                                      2.000000
# hour                                     2.000000
# minute                                  41.000000
# second                                   0.000000
# Name: 8, dtype: float64
# Model Predicted of Row 8 in Test Data is Voltage Surge
